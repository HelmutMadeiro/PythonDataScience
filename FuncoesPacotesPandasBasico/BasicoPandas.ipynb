# %%
import pandas as pd
carros = ['jetta variant', 'Passat', 'Crossfox']

#as series, arrays unidimensionais rotulados capazes de armazenar qualquer tipo de dado.
#Os rótulos das linhas de uma series são conhecidos como index,

pd.Series(carros)

dados = [
    {'Nome': 'Jetta Variant', 'Motor': 'Motor 4.0 Turbo', 'Ano': 2003, 'Quilometragem': 44410.0, 'Zero_km': False, 'Valor': 88078.64},
    {'Nome': 'Passat', 'Motor': 'Motor Diesel', 'Ano': 1991, 'Quilometragem': 5712.0, 'Zero_km': False, 'Valor': 106161.94},
    {'Nome': 'Crossfox', 'Motor': 'Motor Diesel V8', 'Ano': 1990, 'Quilometragem': 37123.0, 'Zero_km': False, 'Valor': 72832.16}
]

dataset3 = pd.DataFrame(dados)

pd.set_option('display.max_rows',10)
pd.set_option('display.max_columns',100)

dataset = pd.read_csv ('dados/db.csv',sep =';',index_col=0)

dataset = pd.DataFrame(dataset)
#dataset.dtypes
#dataset.info()
#dataset[['Quilometragem','Valor']].describe()



dataset.head(2)

dataset[['Valor']]
# Out:
#                            Valor
# Nome
# Jetta Variant           88078.64
# Passat                 106161.94
# Crossfox                72832.16
# DS5                    124549.07
# Aston Martin DB4        92612.10
# ...                          ...
# Phantom 2013            51759.58
# Cadillac Ciel concept   51667.06
# Classe GLK              68934.03
# Aston Martin DB5       122110.90
# Macan                   90381.47
#
# [258 rows x 1 columns]

# %%
#vai bucar pelo rotulo (nome das colunas )
dataset.loc[['Passat','DS5']]#selecionado pelo index
# Out:
#                   Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat     Motor Diesel  1991         5712.0    False
# DS5     Motor 2.4 Turbo  2019            NaN     True
#
#                                                Acessórios      Valor
# Nome
# Passat  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# DS5     ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07

# %%
dataset.loc[['Passat','DS5'],['Motor','Valor']] # seleciondo pelo index e pegando duas colunas
# Out:
#                   Motor      Valor
# Nome
# Passat     Motor Diesel  106161.94
# DS5     Motor 2.4 Turbo  124549.07

# %%
#faz a busca pelo index numerico
dataset.iloc[1]
# Out:
# Motor                                                 Motor Diesel
# Ano                                                           1991
# Quilometragem                                               5712.0
# Zero_km                                                      False
# Acessórios       ['Central multimídia', 'Teto panorâmico', 'Fre...
# Valor                                                    106161.94
# Name: Passat, dtype: object

# %%
dataset.iloc[[1]]
# Out:
#                Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat  Motor Diesel  1991         5712.0    False
#
#                                                Acessórios      Valor
# Nome
# Passat  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94

# %%
dataset.iloc[1:4]
# Out:
#                     Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat       Motor Diesel  1991         5712.0    False
# Crossfox  Motor Diesel V8  1990        37123.0    False
# DS5       Motor 2.4 Turbo  2019            NaN     True
#
#                                                  Acessórios      Valor
# Nome
# Passat    ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox  ['Piloto automático', 'Controle de estabilidad...   72832.16
# DS5       ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07

# %%
dataset.iloc[1:4,[0,5,2]] #1:4, buscando por linda |[0,5,2] buscando por coluna
# Out:
#                     Motor      Valor  Quilometragem
# Nome
# Passat       Motor Diesel  106161.94         5712.0
# Crossfox  Motor Diesel V8   72832.16        37123.0
# DS5       Motor 2.4 Turbo  124549.07            NaN

# %%
dataset.iloc[:,[0,5,2]]

# %%
import pandas as pd

dados = {
    'Nome': ['Jetta', 'Passat', 'Crossfox', 'DS5', 'Fusca'], 
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8', 'Motor 2.0', 'Motor 1.6'],
    'Ano': [2019, 2003, 1991, 2019, 1990],
    'Quilometragem': [0.0, 5712.0, 37123.0, 0.0, 120000.0],
    'Zero_km': [True, False, False, True, False],
    'Valor': [88000.0, 106000.0, 72000.0, 89000.0, 32000.0]
}

dataset = pd.DataFrame(dados)

# %%
dataset [1:3][['Nome','Ano','Quilometragem','Valor']]
# Out:
#        Nome   Ano  Quilometragem     Valor
# 1    Passat  2003         5712.0  106000.0
# 2  Crossfox  1991        37123.0   72000.0

# %%
import pandas as pd

dados = {
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8', 'Motor 2.0', 'Motor 1.6'],
    'Ano': [2019, 2003, 1991, 2019, 1990],
    'Quilometragem': [0.0, 5712.0, 37123.0, 0.0, 120000.0],
    'Zero_km': [True, False, False, True, False],
    'Valor': [88000.0, 106000.0, 72000.0, 89000.0, 32000.0]
}

dataset = pd.DataFrame(dados, index = ['Jetta', 'Passat', 'Crossfox', 'DS5', 'Fusca'])

# %%
dataset
# Out:
#                     Motor   Ano  Quilometragem  Zero_km     Valor
# Jetta     Motor 4.0 Turbo  2019            0.0     True   88000.0
# Passat       Motor Diesel  2003         5712.0    False  106000.0
# Crossfox  Motor Diesel V8  1991        37123.0    False   72000.0
# DS5             Motor 2.0  2019            0.0     True   89000.0
# Fusca           Motor 1.6  1990       120000.0    False   32000.0

# %%
#Utilizando .loc, podemos fazer seleções 
#utilizando os rótulos das linhas e 
#colunas de um DataFrame.

dataset.loc[['Passat','DS5'],['Motor','Valor']]
# Out:
#                Motor     Valor
# Passat  Motor Diesel  106000.0
# DS5        Motor 2.0   89000.0

# %%
#Utilizando .iloc, as seleções são feitas pela 
#posição das linhas e colunas, isto é, utilizando
#os índices numéricos do DataFrame.

dataset.iloc[1:3,[0,4]]
# Out:
#                     Motor     Valor
# Passat       Motor Diesel  106000.0
# Crossfox  Motor Diesel V8   72000.0

# %%
dataset = pd.read_csv ('dados/db.csv',sep =';',index_col=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-278fcb8f5745> in <module>
# ----> 1 dataset = pd.read_csv ('dados/db.csv',sep =';',index_col=0)
#
# NameError: name 'pd' is not defined

# %%
dataset.head()
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant     Motor 4.0 Turbo  2003        44410.0    False
# Passat               Motor Diesel  1991         5712.0    False
# Crossfox          Motor Diesel V8  1990        37123.0    False
# DS5               Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                                          Acessórios      Valor
# Nome
# Jetta Variant     ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# Passat            ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox          ['Piloto automático', 'Controle de estabilidad...   72832.16
# DS5               ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# Aston Martin DB4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
select = dataset.Motor == 'Motor Diesel'
dataset[select]
# Out:
#                               Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat                 Motor Diesel  1991         5712.0    False
# Effa Hafei Picape Baú  Motor Diesel  1991       102959.0    False
# Sorento                Motor Diesel  2019            NaN     True
# New Fiesta Hatch       Motor Diesel  2017       118895.0    False
# Kangoo Express         Motor Diesel  2007        29132.0    False
# ...                             ...   ...            ...      ...
# Dodge Dakota           Motor Diesel  1993        71544.0    False
# i30 CW                 Motor Diesel  2015         8497.0    False
# Série 7 Sedã           Motor Diesel  2019            NaN     True
# V60                    Motor Diesel  2004        91840.0    False
# Aston Martin DB5       Motor Diesel  1996         7685.0    False
#
#                                                               Acessórios  \
# Nome
# Passat                 ['Central multimídia', 'Teto panorâmico', 'Fre...
# ...

# %%
dataset[(dataset.Motor == 'Motor Diesel') & (dataset.Zero_km == True)] # primeiro tipo de filtros
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Sorento              Motor Diesel  2019            NaN     True
# Cielo Hatch          Motor Diesel  2019            NaN     True
# Camry                Motor Diesel  2019            NaN     True
# Aston Martin Virage  Motor Diesel  2019            NaN     True
# Série 7 Sedã         Motor Diesel  2019            NaN     True
#
#                                                             Acessórios  \
# Nome
# Sorento              ['Sensor de chuva', 'Câmera de estacionamento'...
# Cielo Hatch          ['Painel digital', 'Central multimídia', 'Câme...
# Camry                ['Travas elétricas', 'Rodas de liga', 'Sensor ...
# Aston Martin Virage  ['Travas elétricas', 'Controle de tração', 'Câ...
# Série 7 Sedã         ['Vidros elétricos', 'Travas elétricas', 'Roda...
#
#                          Valor
# Nome
# Sorento               81399.35
# Cielo Hatch          145197.70
# Camry                138597.27
# ...

# %%
dataset.query('Motor == "Motor Diesel" and Zero_km == True')# filtro com querys
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Sorento              Motor Diesel  2019            NaN     True
# Cielo Hatch          Motor Diesel  2019            NaN     True
# Camry                Motor Diesel  2019            NaN     True
# Aston Martin Virage  Motor Diesel  2019            NaN     True
# Série 7 Sedã         Motor Diesel  2019            NaN     True
#
#                                                             Acessórios  \
# Nome
# Sorento              ['Sensor de chuva', 'Câmera de estacionamento'...
# Cielo Hatch          ['Painel digital', 'Central multimídia', 'Câme...
# Camry                ['Travas elétricas', 'Rodas de liga', 'Sensor ...
# Aston Martin Virage  ['Travas elétricas', 'Controle de tração', 'Câ...
# Série 7 Sedã         ['Vidros elétricos', 'Travas elétricas', 'Roda...
#
#                          Valor
# Nome
# Sorento               81399.35
# Cielo Hatch          145197.70
# Camry                138597.27
# ...

# %%
import pandas as pd

dados = {
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8', 'Motor Diesel', 'Motor 1.6'],
    'Ano': [2019, 2003, 1991, 2019, 1990],
    'Quilometragem': [0.0, 5712.0, 37123.0, 0.0, 120000.0],
    'Zero_km': [True, False, False, True, False],
    'Valor': [88000.0, 106000.0, 72000.0, 89000.0, 32000.0]
}

dataset = pd.DataFrame(dados, index = ['Jetta', 'Passat', 'Crossfox', 'DS5', 'Fusca'])
dataset
# Out:
#                     Motor   Ano  Quilometragem  Zero_km     Valor
# Jetta     Motor 4.0 Turbo  2019            0.0     True   88000.0
# Passat       Motor Diesel  2003         5712.0    False  106000.0
# Crossfox  Motor Diesel V8  1991        37123.0    False   72000.0
# DS5          Motor Diesel  2019            0.0     True   89000.0
# Fusca           Motor 1.6  1990       120000.0    False   32000.0

# %%
dataset.query('Motor == "Motor Diesel" or Ano == 2019')
# Out:
#                   Motor   Ano  Quilometragem  Zero_km     Valor
# Jetta   Motor 4.0 Turbo  2019            0.0     True   88000.0
# Passat     Motor Diesel  2003         5712.0    False  106000.0
# DS5        Motor Diesel  2019            0.0     True   89000.0

# %%
dataset.query('Motor == "Motor Diesel" or Zero_km == True')
# Out:
#                   Motor   Ano  Quilometragem  Zero_km     Valor
# Jetta   Motor 4.0 Turbo  2019            0.0     True   88000.0
# Passat     Motor Diesel  2003         5712.0    False  106000.0
# DS5        Motor Diesel  2019            0.0     True   89000.0

# %%
dataset[(dataset.Motor=="Motor Diesel") | (dataset.Zero_km ==True)]
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat               Motor Diesel  1991         5712.0    False
# DS5               Motor 2.4 Turbo  2019            NaN     True
# A5                Motor 4.0 Turbo  2019            NaN     True
# J5                       Motor V6  2019            NaN     True
# A3                   Motor 1.0 8v  2019            NaN     True
# ...                           ...   ...            ...      ...
# Benni Mini               Motor V8  2019            NaN     True
# Uno               Motor Diesel V6  2019            NaN     True
# Santa Fe            Motor 3.0 32v  2019            NaN     True
# XC60              Motor 4.0 Turbo  2019            NaN     True
# Aston Martin DB5     Motor Diesel  1996         7685.0    False
#
#                                                          Acessórios      Valor
# Nome
# Passat            ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# ...

# %%
for index, row in dataset.iterrows(): # pelo o index e as colunas  
    if(2019 - row['Ano'] !=0): 
        dataset.loc[index,'km_media'] = row['Quilometragem'] / (2019 - row['Ano']) #crio uma nova coluna 
    else:
        dataset.loc[index,'km_media'] = 0
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %%
list(dataset.items())
# Out:
# [('Motor',
#   Nome
#   Jetta Variant                  Motor 4.0 Turbo
#   Passat                            Motor Diesel
#   Crossfox                       Motor Diesel V8
#   DS5                            Motor 2.4 Turbo
#   Aston Martin DB4               Motor 2.4 Turbo
#                                    ...
#   Phantom 2013                          Motor V8
#   Cadillac Ciel concept                 Motor V8
#   Classe GLK               Motor 5.0 V8 Bi-Turbo
#   Aston Martin DB5                  Motor Diesel
#   Macan                          Motor Diesel V6
#   Name: Motor, Length: 258, dtype: object),
#  ('Ano',
#   Nome
#   Jetta Variant            2003
#   Passat                   1991
#   Crossfox                 1990
#   DS5                      2019
#   Aston Martin DB4         2006
#                            ...
#   Phantom 2013             2014
#   Cadillac Ciel concept    1991
#   Classe GLK               2002
#   Aston Martin DB5         1996
# ...

# %%
list(dataset.itertuples())
# Out:
# [Pandas(Index='Jetta Variant', Motor='Motor 4.0 Turbo', Ano=2003, Quilometragem=44410.0, Zero_km=False, Acessórios="['Rodas de liga', 'Travas elétricas', 'Piloto automático', 'Bancos de couro', 'Ar condicionado', 'Sensor de estacionamento', 'Sensor crepuscular', 'Sensor de chuva']", Valor=88078.64, km_media=2775.625),
#  Pandas(Index='Passat', Motor='Motor Diesel', Ano=1991, Quilometragem=5712.0, Zero_km=False, Acessórios="['Central multimídia', 'Teto panorâmico', 'Freios ABS', '4 X 4', 'Painel digital', 'Piloto automático', 'Bancos de couro', 'Câmera de estacionamento']", Valor=106161.94, km_media=204.0),
#  Pandas(Index='Crossfox', Motor='Motor Diesel V8', Ano=1990, Quilometragem=37123.0, Zero_km=False, Acessórios="['Piloto automático', 'Controle de estabilidade', 'Sensor crepuscular', 'Freios ABS', 'Câmbio automático', 'Bancos de couro', 'Central multimídia', 'Vidros elétricos']", Valor=72832.16, km_media=1280.103448275862),
# ...

# %%
#tratamento de dados 
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258 entries, Jetta Variant to Macan
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Motor          258 non-null    object
#  1   Ano            258 non-null    int64
#  2   Quilometragem  197 non-null    float64
#  3   Zero_km        258 non-null    bool
#  4   Acessórios     258 non-null    object
#  5   Valor          258 non-null    float64
#  6   km_media       258 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(2)
# memory usage: 22.5+ KB

# %%
#retona um bolean aonde true é nan e false contem registro
dataset.Quilometragem.isna()
# Out:
# Nome
# Jetta Variant            False
# Passat                   False
# Crossfox                 False
# DS5                       True
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5         False
# Macan                    False
# Name: Quilometragem, Length: 258, dtype: bool

# %%
#selecionando apenas os nan na quilometragem
dataset[dataset.Quilometragem.isna()]
# Out:
#                                 Motor   Ano  Quilometragem  Zero_km  \
# Nome
# DS5                   Motor 2.4 Turbo  2019            NaN     True
# A5                    Motor 4.0 Turbo  2019            NaN     True
# J5                           Motor V6  2019            NaN     True
# A3                       Motor 1.0 8v  2019            NaN     True
# Série 1 M                    Motor V8  2019            NaN     True
# ...                               ...   ...            ...      ...
# Lamborghini Reventón  Motor 4.0 Turbo  2019            NaN     True
# Benni Mini                   Motor V8  2019            NaN     True
# Uno                   Motor Diesel V6  2019            NaN     True
# Santa Fe                Motor 3.0 32v  2019            NaN     True
# XC60                  Motor 4.0 Turbo  2019            NaN     True
#
#                                                              Acessórios  \
# Nome
# ...

# %%
#inserir o registro dentro do dataframe 
dataset.fillna(0, inplace = True) # não tem retorno mas o inplece sobrescreve os nan

# %%
dataset = pd.read_csv ('dados/db.csv',sep =';',index_col=0)
#deletar os nan
dataset.dropna(subset = ['Quilometragem'],inplace = True)
